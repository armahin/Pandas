# %% [markdown]
# <a href="https://colab.research.google.com/github/armahin/Pandas/blob/main/2.%20Pandas%20DataFrame.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **Pandas Dataframe**
#
# A whole tabular data is called DataFrame
#
# A single row or a single column is called Series

# %%
import numpy as np
import pandas as pd

# %% [markdown]
# ## **Creating DataFrame**

# %%
# Using Lists

student_data = [
    [100,80,10],
    [90,70,7],
    [120,100,14],
    [80,50,2]
]
pd.DataFrame(student_data,columns = ['IQ','MARKS','PACKAGE'])
# Out:
#     IQ  MARKS  PACKAGE
# 0  100     80       10
# 1   90     70        7
# 2  120    100       14
# 3   80     50        2

# %%
# Using Dicts
student_dict = {
    'ID': [100,90,120,80],
    'MARKS' : [80,70,100,50],
    'PACKAGE': [10,7,14,2]
}
students = pd.DataFrame(student_dict)

# %%
students
# Out:
#     ID  MARKS  PACKAGE
# 0  100     80       10
# 1   90     70        7
# 2  120    100       14
# 3   80     50        2

# %%
#Using read_csv
movies = pd.read_csv('movies.csv')

# %%
movies
# Out:
#                                    title_x     imdb_id  \
# 0                 Uri: The Surgical Strike   tt8291224
# 1                            Battalion 609   tt9472208
# 2     The Accidental Prime Minister (film)   tt6986710
# 3                          Why Cheat India   tt8108208
# 4                          Evening Shadows   tt6028796
# ...                                    ...         ...
# 1624                 Tera Mera Saath Rahen   tt0301250
# 1625                  Yeh Zindagi Ka Safar   tt0298607
# 1626                       Sabse Bada Sukh   tt0069204
# 1627                                 Daaka  tt10833860
# 1628                              Humsafar   tt2403201
#
#                                             poster_path  \
# 0     https://upload.wikimedia.org/wikipedia/en/thum...
# 1                                                   NaN
# 2     https://upload.wikimedia.org/wikipedia/en/thum...
# 3     https://upload.wikimedia.org/wikipedia/en/thum...
# ...

# %%
ipl = pd.read_csv('ipl-matches.csv')
ipl
# Out:
#           ID        City        Date   Season  MatchNumber  \
# 0    1312200   Ahmedabad  2022-05-29     2022        Final
# 1    1312199   Ahmedabad  2022-05-27     2022  Qualifier 2
# 2    1312198     Kolkata  2022-05-25     2022   Eliminator
# 3    1312197     Kolkata  2022-05-24     2022  Qualifier 1
# 4    1304116      Mumbai  2022-05-22     2022           70
# ..       ...         ...         ...      ...          ...
# 945   335986     Kolkata  2008-04-20  2007/08            4
# 946   335985      Mumbai  2008-04-20  2007/08            5
# 947   335984       Delhi  2008-04-19  2007/08            3
# 948   335983  Chandigarh  2008-04-19  2007/08            2
# 949   335982   Bangalore  2008-04-18  2007/08            1
#
#                            Team1                        Team2  \
# 0               Rajasthan Royals               Gujarat Titans
# 1    Royal Challengers Bangalore             Rajasthan Royals
# 2    Royal Challengers Bangalore         Lucknow Super Giants
# ...

# %% [markdown]
# ## **DataFrame Attributes and Methods**

# %% [markdown]
# **shape** - shows how many rows and columns are there

# %%
movies.shape
# Out:
# (1629, 18)

# %%
ipl.shape
# Out:
# (950, 20)

# %% [markdown]
# **dtypes** - shows data types of all the columns

# %%
movies.dtypes
# Out:
# title_x              object
# imdb_id              object
# poster_path          object
# wiki_link            object
# title_y              object
# original_title       object
# is_adult              int64
# year_of_release       int64
# runtime              object
# genres               object
# imdb_rating         float64
# imdb_votes            int64
# story                object
# summary              object
# tagline              object
# actors               object
# wins_nominations     object
# release_date         object
# dtype: object

# %% [markdown]
# **index** - entire index will be shown

# %%
movies.index
# Out:
# RangeIndex(start=0, stop=1629, step=1)

# %% [markdown]
# **columns** - will fetch all the columns of the dataset

# %%
movies.columns
# Out:
# Index(['title_x', 'imdb_id', 'poster_path', 'wiki_link', 'title_y',
#        'original_title', 'is_adult', 'year_of_release', 'runtime', 'genres',
#        'imdb_rating', 'imdb_votes', 'story', 'summary', 'tagline', 'actors',
#        'wins_nominations', 'release_date'],
#       dtype='object')

# %% [markdown]
# **values** - will fetch all the values of the dataset

# %%
students.values
# Out:
# array([[100,  80,  10],
#        [ 90,  70,   7],
#        [120, 100,  14],
#        [ 80,  50,   2]])

# %% [markdown]
# **head & tail** - shows top 5 & bottom 5

# %%
movies.head()
# Out:
#                                 title_x    imdb_id  \
# 0              Uri: The Surgical Strike  tt8291224
# 1                         Battalion 609  tt9472208
# 2  The Accidental Prime Minister (film)  tt6986710
# 3                       Why Cheat India  tt8108208
# 4                       Evening Shadows  tt6028796
#
#                                          poster_path  \
# 0  https://upload.wikimedia.org/wikipedia/en/thum...
# 1                                                NaN
# 2  https://upload.wikimedia.org/wikipedia/en/thum...
# 3  https://upload.wikimedia.org/wikipedia/en/thum...
# 4                                                NaN
#
#                                            wiki_link  \
# 0  https://en.wikipedia.org/wiki/Uri:_The_Surgica...
# 1        https://en.wikipedia.org/wiki/Battalion_609
# 2  https://en.wikipedia.org/wiki/The_Accidental_P...
# 3      https://en.wikipedia.org/wiki/Why_Cheat_India
# 4      https://en.wikipedia.org/wiki/Evening_Shadows
#
# ...

# %%
# Will show as we want if we pass argument
movies.head(2)
# Out:
#                     title_x    imdb_id  \
# 0  Uri: The Surgical Strike  tt8291224
# 1             Battalion 609  tt9472208
#
#                                          poster_path  \
# 0  https://upload.wikimedia.org/wikipedia/en/thum...
# 1                                                NaN
#
#                                            wiki_link  \
# 0  https://en.wikipedia.org/wiki/Uri:_The_Surgica...
# 1        https://en.wikipedia.org/wiki/Battalion_609
#
#                     title_y            original_title  is_adult  \
# 0  Uri: The Surgical Strike  Uri: The Surgical Strike         0
# 1             Battalion 609             Battalion 609         0
#
#    year_of_release runtime            genres  imdb_rating  imdb_votes  \
# 0             2019     138  Action|Drama|War          8.4       35112
# 1             2019     131               War          4.1          73
#
#                                                story  \
# ...

# %% [markdown]
# **sample** - will just show random rows

# %%
movies.sample(5)
# Out:
#                      title_x    imdb_id  \
# 29            Setters (film)  tt9239772
# 1097      Life in a... Metro  tt0800956
# 1204  The Killer (2006 film)  tt0833484
# 1425              The Bypass  tt0397941
# 1071                  Dhokha  tt1090650
#
#                                             poster_path  \
# 29    https://upload.wikimedia.org/wikipedia/en/thum...
# 1097  https://upload.wikimedia.org/wikipedia/en/thum...
# 1204  https://upload.wikimedia.org/wikipedia/en/thum...
# 1425  https://upload.wikimedia.org/wikipedia/commons...
# 1071  https://upload.wikimedia.org/wikipedia/en/thum...
#
#                                               wiki_link          title_y  \
# 29         https://en.wikipedia.org/wiki/Setters_(film)          Setters
# 1097   https://en.wikipedia.org/wiki/Life_in_a..._Metro  Life in a Metro
# 1204  https://en.wikipedia.org/wiki/The_Killer_(2006...       The Killer
# 1425           https://en.wikipedia.org/wiki/The_Bypass       The Bypass
# ...

# %% [markdown]
# **info** - will provide high level info in one go

# %%
movies.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1629 entries, 0 to 1628
# Data columns (total 18 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   title_x           1629 non-null   object
#  1   imdb_id           1629 non-null   object
#  2   poster_path       1526 non-null   object
#  3   wiki_link         1629 non-null   object
#  4   title_y           1629 non-null   object
#  5   original_title    1629 non-null   object
#  6   is_adult          1629 non-null   int64
#  7   year_of_release   1629 non-null   int64
#  8   runtime           1629 non-null   object
#  9   genres            1629 non-null   object
#  10  imdb_rating       1629 non-null   float64
#  11  imdb_votes        1629 non-null   int64
#  12  story             1609 non-null   object
#  13  summary           1629 non-null   object
#  14  tagline           557 non-null    object
#  15  actors            1624 non-null   object
# ...

# %% [markdown]
# **describe** - gives a mathematical summary

# %%
movies.describe()
# Out:
#        is_adult  year_of_release  imdb_rating     imdb_votes
# count    1629.0      1629.000000  1629.000000    1629.000000
# mean        0.0      2010.263966     5.557459    5384.263352
# std         0.0         5.381542     1.567609   14552.103231
# min         0.0      2001.000000     0.000000       0.000000
# 25%         0.0      2005.000000     4.400000     233.000000
# 50%         0.0      2011.000000     5.600000    1000.000000
# 75%         0.0      2015.000000     6.800000    4287.000000
# max         0.0      2019.000000     9.400000  310481.000000

# %% [markdown]
# **isnull** - checks if there is any null values

# %%
movies.isnull().sum()
# Out:
# title_x                0
# imdb_id                0
# poster_path          103
# wiki_link              0
# title_y                0
# original_title         0
# is_adult               0
# year_of_release        0
# runtime                0
# genres                 0
# imdb_rating            0
# imdb_votes             0
# story                 20
# summary                0
# tagline             1072
# actors                 5
# wins_nominations     922
# release_date         107
# dtype: int64

# %% [markdown]
# **duplicated** - if there is duplicated rows or not

# %%
movies.duplicated().sum()
# Out:
# 0

# %% [markdown]
# **rename** - renames the column name

# %%
students
# Out:
#     ID  MARKS  PACKAGE
# 0  100     80       10
# 1   90     70        7
# 2  120    100       14
# 3   80     50        2

# %%
students.rename(columns = {'MARKS':'PERCENT'} )
# Out:
#     ID  PERCENT  PACKAGE
# 0  100       80       10
# 1   90       70        7
# 2  120      100       14
# 3   80       50        2

# %%
students
# Out:
#     ID  MARKS  PACKAGE
# 0  100     80       10
# 1   90     70        7
# 2  120    100       14
# 3   80     50        2

# %% [markdown]
# So this was not a permanent change

# %% [markdown]
# To make this permanently changed we have to make inplace = True

# %%
students.rename(columns = {'MARKS':'PERCENT'}, inplace = True )

# %%
students
# Out:
#     ID  PERCENT  PACKAGE
# 0  100       80       10
# 1   90       70        7
# 2  120      100       14
# 3   80       50        2

# %% [markdown]
# ## **Math Methods**

# %% [markdown]
# **sum** - sums values in columns

# %%
students.sum() # axis = 1 will sum values in rows
# Out:
# ID         390
# PERCENT    300
# PACKAGE     33
# dtype: int64

# %% [markdown]
# **mean** -

# %%
students.mean(axis = 1)
# Out:
# 0    63.333333
# 1    55.666667
# 2    78.000000
# 3    44.000000
# dtype: float64

# %% [markdown]
# **var** -

# %%
students.var()
# Out:
# ID         291.666667
# PERCENT    433.333333
# PACKAGE     25.583333
# dtype: float64

# %% [markdown]
# ## **Selecting cols from a DataFrame**

# %% [markdown]
# **If we want to fetch a single column from a DataFrame**

# %%
movies.head(1)
# Out:
#                     title_x    imdb_id  \
# 0  Uri: The Surgical Strike  tt8291224
#
#                                          poster_path  \
# 0  https://upload.wikimedia.org/wikipedia/en/thum...
#
#                                            wiki_link  \
# 0  https://en.wikipedia.org/wiki/Uri:_The_Surgica...
#
#                     title_y            original_title  is_adult  \
# 0  Uri: The Surgical Strike  Uri: The Surgical Strike         0
#
#    year_of_release runtime            genres  imdb_rating  imdb_votes  \
# 0             2019     138  Action|Drama|War          8.4       35112
#
#                                                story  \
# 0  Divided over five chapters  the film chronicle...
#
#                                              summary tagline  \
# 0  Indian army special forces execute a covert op...     NaN
#
#                                               actors wins_nominations  \
# 0  Vicky Kaushal|Paresh Rawal|Mohit Raina|Yami Ga...           4 wins
#
# ...

# %%
# Let's say we want to take only the title_x column

# %%
movies['title_x'] # This is a series
# Out:
# 0                   Uri: The Surgical Strike
# 1                              Battalion 609
# 2       The Accidental Prime Minister (film)
# 3                            Why Cheat India
# 4                            Evening Shadows
#                         ...
# 1624                   Tera Mera Saath Rahen
# 1625                    Yeh Zindagi Ka Safar
# 1626                         Sabse Bada Sukh
# 1627                                   Daaka
# 1628                                Humsafar
# Name: title_x, Length: 1629, dtype: object

# %% [markdown]
# **If we want to fetch multiple columns from a DataFrame**

# %%
#Let's say we want to take out the original_title,is_adult,year_of_release
#Using fancy indexing here
movies[["original_title","is_adult","year_of_release"]] #This will be a DataFrame
# Out:
#                      original_title  is_adult  year_of_release
# 0          Uri: The Surgical Strike         0             2019
# 1                     Battalion 609         0             2019
# 2     The Accidental Prime Minister         0             2019
# 3                   Why Cheat India         0             2019
# 4                   Evening Shadows         0             2018
# ...                             ...       ...              ...
# 1624          Tera Mera Saath Rahen         0             2001
# 1625           Yeh Zindagi Ka Safar         0             2001
# 1626                Sabse Bada Sukh         0             2018
# 1627                          Daaka         0             2019
# 1628                       Humsafar         0             2011
#
# [1629 rows x 3 columns]

# %% [markdown]
# ## **Selecting rows from a DataFrame**
#
# - **iloc** - searches using index positions
# - **loc** - searches using index labels

# %% [markdown]
# ### **iloc**

# %% [markdown]
# **Single Row**

# %%
#Let's create the data
student_data = {
    'name' : ['Arian','Mahin','Sikder','Kabir','Ety','Rifat'],
    'iq':[100,90,120,80,0,23],
    'marks' : [80,70,100,50,0,51],
    'package' : [10,7,14,2,0,64]
}
studentdata = pd.DataFrame(student_data)
studentdata.set_index('name',inplace=True)
studentdata
# Out:
#          iq  marks  package
# name
# Arian   100     80       10
# Mahin    90     70        7
# Sikder  120    100       14
# Kabir    80     50        2
# Ety       0      0        0
# Rifat    23     51       64

# %%
# Now how can we fetch rows

# %%
movies.iloc[0]
# Out:
# title_x                                      Uri: The Surgical Strike
# imdb_id                                                     tt8291224
# poster_path         https://upload.wikimedia.org/wikipedia/en/thum...
# wiki_link           https://en.wikipedia.org/wiki/Uri:_The_Surgica...
# title_y                                      Uri: The Surgical Strike
# original_title                               Uri: The Surgical Strike
# is_adult                                                            0
# year_of_release                                                  2019
# runtime                                                           138
# genres                                               Action|Drama|War
# imdb_rating                                                       8.4
# imdb_votes                                                      35112
# story               Divided over five chapters  the film chronicle...
# ...

# %% [markdown]
# **Multiple Row**

# %%
movies.iloc[0:5]
# Out:
#                                 title_x    imdb_id  \
# 0              Uri: The Surgical Strike  tt8291224
# 1                         Battalion 609  tt9472208
# 2  The Accidental Prime Minister (film)  tt6986710
# 3                       Why Cheat India  tt8108208
# 4                       Evening Shadows  tt6028796
#
#                                          poster_path  \
# 0  https://upload.wikimedia.org/wikipedia/en/thum...
# 1                                                NaN
# 2  https://upload.wikimedia.org/wikipedia/en/thum...
# 3  https://upload.wikimedia.org/wikipedia/en/thum...
# 4                                                NaN
#
#                                            wiki_link  \
# 0  https://en.wikipedia.org/wiki/Uri:_The_Surgica...
# 1        https://en.wikipedia.org/wiki/Battalion_609
# 2  https://en.wikipedia.org/wiki/The_Accidental_P...
# 3      https://en.wikipedia.org/wiki/Why_Cheat_India
# 4      https://en.wikipedia.org/wiki/Evening_Shadows
#
# ...

# %%
#fancy indexing
movies.iloc[[0,4,5]]
# Out:
#                     title_x    imdb_id  \
# 0  Uri: The Surgical Strike  tt8291224
# 4           Evening Shadows  tt6028796
# 5               Soni (film)  tt6078866
#
#                                          poster_path  \
# 0  https://upload.wikimedia.org/wikipedia/en/thum...
# 4                                                NaN
# 5  https://upload.wikimedia.org/wikipedia/en/thum...
#
#                                            wiki_link  \
# 0  https://en.wikipedia.org/wiki/Uri:_The_Surgica...
# 4      https://en.wikipedia.org/wiki/Evening_Shadows
# 5          https://en.wikipedia.org/wiki/Soni_(film)
#
#                     title_y            original_title  is_adult  \
# 0  Uri: The Surgical Strike  Uri: The Surgical Strike         0
# 4           Evening Shadows           Evening Shadows         0
# 5                      Soni                      Soni         0
#
#    year_of_release runtime            genres  imdb_rating  imdb_votes  \
# ...

# %% [markdown]
# ### **loc**

# %% [markdown]
# **Single Row**

# %%
studentdata
# Out:
#          iq  marks  package
# name
# Arian   100     80       10
# Mahin    90     70        7
# Sikder  120    100       14
# Kabir    80     50        2
# Ety       0      0        0
# Rifat    23     51       64

# %%
studentdata.loc['Arian']
# Out:
# iq         100
# marks       80
# package     10
# Name: Arian, dtype: int64

# %% [markdown]
# **Multiple Row**

# %%
studentdata.loc['Arian':'Sikder']
# Out:
#          iq  marks  package
# name
# Arian   100     80       10
# Mahin    90     70        7
# Sikder  120    100       14

# %%
#Fancy Indexing
studentdata.loc[['Arian','Sikder','Ety']]
# Out:
#          iq  marks  package
# name
# Arian   100     80       10
# Sikder  120    100       14
# Ety       0      0        0

# %% [markdown]
# **Selecting both columns and rows**

# %%
movies.iloc[0:4,0:3]
# Out:
#                                 title_x    imdb_id  \
# 0              Uri: The Surgical Strike  tt8291224
# 1                         Battalion 609  tt9472208
# 2  The Accidental Prime Minister (film)  tt6986710
# 3                       Why Cheat India  tt8108208
#
#                                          poster_path
# 0  https://upload.wikimedia.org/wikipedia/en/thum...
# 1                                                NaN
# 2  https://upload.wikimedia.org/wikipedia/en/thum...
# 3  https://upload.wikimedia.org/wikipedia/en/thum...

# %% [markdown]
# ## **Filtering a DataFrame**

# %%
ipl.head(2)
# Out:
#         ID       City        Date Season MatchNumber  \
# 0  1312200  Ahmedabad  2022-05-29   2022       Final
# 1  1312199  Ahmedabad  2022-05-27   2022       Final
#
#                          Team1             Team2  \
# 0             Rajasthan Royals    Gujarat Titans
# 1  Royal Challengers Bangalore  Rajasthan Royals
#
#                               Venue        TossWinner TossDecision SuperOver  \
# 0  Narendra Modi Stadium, Ahmedabad  Rajasthan Royals          bat         N
# 1  Narendra Modi Stadium, Ahmedabad  Rajasthan Royals        field         N
#
#         WinningTeam    WonBy  Margin method Player_of_Match  \
# 0    Gujarat Titans  Wickets     7.0    NaN       HH Pandya
# 1  Rajasthan Royals  Wickets     7.0    NaN      JC Buttler
#
#                                         Team1Players  \
# 0  ['YBK Jaiswal', 'JC Buttler', 'SV Samson', 'D ...
# 1  ['V Kohli', 'F du Plessis', 'RM Patidar', 'GJ ...
#
# ...

# %%
# find all the final winners
mask = ipl['MatchNumber'] =='Final'
new_df = ipl[mask]
new_df[['Season','WinningTeam']]

#In one line
ipl[ipl['MatchNumber'] == 'Final'][['Season','WinningTeam']]
# Out:
#       Season                  WinningTeam
# 0       2022               Gujarat Titans
# 1       2022             Rajasthan Royals
# 2       2022  Royal Challengers Bangalore
# 3       2022               Gujarat Titans
# 4       2022                 Punjab Kings
# ..       ...                          ...
# 945  2007/08        Kolkata Knight Riders
# 946  2007/08  Royal Challengers Bangalore
# 947  2007/08             Delhi Daredevils
# 948  2007/08          Chennai Super Kings
# 949  2007/08        Kolkata Knight Riders
#
# [950 rows x 2 columns]

# %%
# how many super over finishes have occured
ipl[ipl["SuperOver"] == 'Y'].shape[0]
# Out:
# 14

# %%
# how many matches has csk won in kolkata
# one way is won = ipl[ipl['City'] == "Kolkata"]["WinningTeam"] == "Chennai Super Kings"
# won.sum()
ipl[(ipl['City'] == "Kolkata") & (ipl["WinningTeam"] == "Chennai Super Kings")].shape[0]
# Out:
# 5

# %%
# toss winner is match winner in percentage
ipl[ipl['TossWinner'] == ipl['WinningTeam']].shape[0] / ipl.shape[0]*100
# Out:
# 51.473684210526315

# %%
# movies with rating higher than 8 and votes>10000
movies.head(2)
# Out:
#                     title_x    imdb_id  \
# 0  Uri: The Surgical Strike  tt8291224
# 1             Battalion 609  tt9472208
#
#                                          poster_path  \
# 0  https://upload.wikimedia.org/wikipedia/en/thum...
# 1                                                NaN
#
#                                            wiki_link  \
# 0  https://en.wikipedia.org/wiki/Uri:_The_Surgica...
# 1        https://en.wikipedia.org/wiki/Battalion_609
#
#                     title_y            original_title  is_adult  \
# 0  Uri: The Surgical Strike  Uri: The Surgical Strike         0
# 1             Battalion 609             Battalion 609         0
#
#    year_of_release runtime            genres  imdb_rating  imdb_votes  \
# 0             2019     138  Action|Drama|War          8.4       35112
# 1             2019     131               War          4.1          73
#
#                                                story  \
# ...

# %%
movies[(movies['imdb_rating'] > 8) & (movies['imdb_votes'] > 10000)].shape[0]
# Out:
# 43

# %%
# Action movies with rating higher than 7.5
mask1 = movies['genres'].str.split('|').apply(lambda x:'Action' in x)
mask2= movies['imdb_rating'] > 7.5
movies[mask1 & mask2].shape[0]
# Out:
# 33

# %%
# write a function that can return the track record of 2 teams against each other
# Out:
# ['mahin', 'sikder', 'arin']

# %% [markdown]
# ## **Adding New Columns**

# %%
movies['Country'] = 'India'

# %%
movies.head()
# Out:
#                                 title_x    imdb_id  \
# 0              Uri: The Surgical Strike  tt8291224
# 1                         Battalion 609  tt9472208
# 2  The Accidental Prime Minister (film)  tt6986710
# 3                       Why Cheat India  tt8108208
# 4                       Evening Shadows  tt6028796
#
#                                          poster_path  \
# 0  https://upload.wikimedia.org/wikipedia/en/thum...
# 1                                                NaN
# 2  https://upload.wikimedia.org/wikipedia/en/thum...
# 3  https://upload.wikimedia.org/wikipedia/en/thum...
# 4                                                NaN
#
#                                            wiki_link  \
# 0  https://en.wikipedia.org/wiki/Uri:_The_Surgica...
# 1        https://en.wikipedia.org/wiki/Battalion_609
# 2  https://en.wikipedia.org/wiki/The_Accidental_P...
# 3      https://en.wikipedia.org/wiki/Why_Cheat_India
# 4      https://en.wikipedia.org/wiki/Evening_Shadows
#
# ...

# %%
#Changing Columns with taking existing columns value
movies.dropna(inplace=True)

# %%
movies['Lead Actor'] = movies['actors'].str.split('|').apply(lambda x: x[0])

# %%
movies.head()
# Out:
#               title_x     imdb_id  \
# 11          Gully Boy   tt2395469
# 34      Yeh Hai India   tt5525846
# 37  Article 15 (film)  tt10324144
# 87            Aiyaary   tt6774212
# 96   Raid (2018 film)   tt7363076
#
#                                           poster_path  \
# 11  https://upload.wikimedia.org/wikipedia/en/thum...
# 34  https://upload.wikimedia.org/wikipedia/en/thum...
# 37  https://upload.wikimedia.org/wikipedia/en/thum...
# 87  https://upload.wikimedia.org/wikipedia/en/thum...
# 96  https://upload.wikimedia.org/wikipedia/en/thum...
#
#                                           wiki_link        title_y  \
# 11          https://en.wikipedia.org/wiki/Gully_Boy      Gully Boy
# 34      https://en.wikipedia.org/wiki/Yeh_Hai_India  Yeh Hai India
# 37  https://en.wikipedia.org/wiki/Article_15_(film)     Article 15
# 87            https://en.wikipedia.org/wiki/Aiyaary        Aiyaary
# 96   https://en.wikipedia.org/wiki/Raid_(2018_film)           Raid
#
# ...

# %% [markdown]
# ## **Important DataFrame Functions**

# %%
# astype -> Changes the datatype of a given column
ipl.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 950 entries, 0 to 949
# Data columns (total 20 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   ID               950 non-null    int64
#  1   City             899 non-null    object
#  2   Date             950 non-null    object
#  3   Season           950 non-null    object
#  4   MatchNumber      950 non-null    object
#  5   Team1            950 non-null    object
#  6   Team2            950 non-null    object
#  7   Venue            950 non-null    object
#  8   TossWinner       950 non-null    object
#  9   TossDecision     950 non-null    object
#  10  SuperOver        946 non-null    object
#  11  WinningTeam      946 non-null    object
#  12  WonBy            950 non-null    object
#  13  Margin           932 non-null    float64
#  14  method           19 non-null     object
#  15  Player_of_Match  946 non-null    object
# ...

# %%
ipl['ID'] = ipl['ID'].astype('int32')

# %%
ipl.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 950 entries, 0 to 949
# Data columns (total 20 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   ID               950 non-null    int32
#  1   City             899 non-null    object
#  2   Date             950 non-null    object
#  3   Season           950 non-null    object
#  4   MatchNumber      950 non-null    object
#  5   Team1            950 non-null    object
#  6   Team2            950 non-null    object
#  7   Venue            950 non-null    object
#  8   TossWinner       950 non-null    object
#  9   TossDecision     950 non-null    object
#  10  SuperOver        946 non-null    object
#  11  WinningTeam      946 non-null    object
#  12  WonBy            950 non-null    object
#  13  Margin           932 non-null    float64
#  14  method           19 non-null     object
#  15  Player_of_Match  946 non-null    object
# ...

# %%
# ipl['Season'] = ipl['Season'].astype('category')
ipl['Team1'] = ipl['Team1'].astype('category')
ipl['Team2'] = ipl['Team2'].astype('category')

# %%
ipl.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 950 entries, 0 to 949
# Data columns (total 20 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   ID               950 non-null    int32
#  1   City             899 non-null    object
#  2   Date             950 non-null    object
#  3   Season           950 non-null    object
#  4   MatchNumber      950 non-null    object
#  5   Team1            950 non-null    category
#  6   Team2            950 non-null    category
#  7   Venue            950 non-null    object
#  8   TossWinner       950 non-null    object
#  9   TossDecision     950 non-null    object
#  10  SuperOver        946 non-null    object
#  11  WinningTeam      946 non-null    object
#  12  WonBy            950 non-null    object
#  13  Margin           932 non-null    float64
#  14  method           19 non-null     object
#  15  Player_of_Match  946 non-null    object
# ...

# %%
# value_counts

# %%
# find which player has own most potm -> in finals and qualifiers

# %%
# Toss decision plot

# %%
# How many matches each team has played
